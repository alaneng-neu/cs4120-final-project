# %%
import joblib
import os

from utils.pipeline_utils import classify_email, display_result, classify_batch, test_emails

# %% [markdown]
# ## Load Pre-trained Models

# %%
# Define models directory
models_dir = '../models'

# Load Stage 1: Spam Detection Model (SVM)
spam_model = joblib.load(os.path.join(models_dir, 'svm_model.joblib'))
spam_vectorizer = joblib.load(os.path.join(models_dir, 'svm_vectorizer.joblib'))

# Load Stage 2: Phishing Type Classification Model (SVM)
phishing_model = joblib.load(os.path.join(models_dir, 'phishing_svm_model.joblib'))
phishing_vectorizer = joblib.load(os.path.join(models_dir, 'phishing_svm_vectorizer.joblib'))

print(f"Spam model classes: {spam_model.classes_}")
print(f"Phishing model classes: {phishing_model.classes_}")
# Out:
# Spam model classes: [0 1]
# Phishing model classes: ['authority_scam' 'credential_harvesting' 'financial_scam'
#  'generic_phishing' 'legitimate' 'romance_dating' 'social_engineering'
#  'social_engineering_advanced' 'tech_support' 'threats' 'urgency']

# %% [markdown]
# ## Test the Pipeline with Examples

# %%
# Classify each test email
print("EMAIL CLASSIFICATION RESULTS")

for i, email in enumerate(test_emails, 1):
    print(f"\n>>> Email #{i}")
    result = classify_email(email, spam_model, spam_vectorizer, phishing_model, phishing_vectorizer)
    display_result(result)
# Out:
# EMAIL CLASSIFICATION RESULTS
#
# >>> Email #1
# 📧 EMAIL CLASSIFICATION RESULT
#
# 📝 Email Preview:
#     Hi John,
#
#     Just wanted to follow up on our meeting yesterday. I've attached the quarterly report
#     as discussed. Let me know if you have any questions.
#
#     Best regards,
#     Sarah
#
# 🔍 Stage 1 - Spam Detection:
#     Result:     Ham
#     Confidence: 100.0%
#
# 📊 FINAL CLASSIFICATION:
#     Result:     ✅ Legitimate Email (Ham)
#     Risk Level: Low
#
# 💡 ADVICE:
#     This email appears to be legitimate, but always verify sender addresses.
#
#
# >>> Email #2
# 📧 EMAIL CLASSIFICATION RESULT
#
# 📝 Email Preview:
#     URGENT: Your account has been compromised!
#
#     We detected suspicious activity on your account. Click the link below to verify
#     your password and secure your account immediately:
#
#     [Ve...
#
# 🔍 Stage 1 - Spam Detection:
#     Result:     Spam
#     Confidence: 99.3%
#
# 🎯 Stage 2 - Phishing Type Classification:
#     Prediction: social_engineering
#     Confidence: 45.3%
#     2nd Best:   credential_harvesting (37.0%)
#
# ⚠️  WARNING
#     ⚠️ LOW CONFIDENCE: The phishing type classification confidence is only 45.3%. The actual threat type may differ.
#
# 📊 FINAL CLASSIFICATION:
#     Result:     🎭 Social Engineering
#     Risk Level: Medium
#
# 💡 ADVICE:
#     Verify requests through official channels before taking action.
#
#
# >>> Email #3
# 📧 EMAIL CLASSIFICATION RESULT
#
# 📝 Email Preview:
#     Congratulations! You have been selected as the winner of our international lottery!
#
#     You have won $5,000,000 USD! To claim your prize, please send us your bank account
#     details and a proce...
#
# 🔍 Stage 1 - Spam Detection:
#     Result:     Spam
#     Confidence: 100.0%
#
# 🎯 Stage 2 - Phishing Type Classification:
#     Prediction: financial_scam
#     Confidence: 96.6%
#     2nd Best:   legitimate (1.8%)
#
# 📊 FINAL CLASSIFICATION:
#     Result:     💰 Financial Scam
#     Risk Level: High
#
# 💡 ADVICE:
#     Never send money or share bank details based on an email request.
#
#
# >>> Email #4
# 📧 EMAIL CLASSIFICATION RESULT
#
# 📝 Email Preview:
#     FINAL NOTICE: IRS Tax Violation
#
#     This is the Internal Revenue Service. Our records show you owe $15,000 in back taxes.
#     Failure to pay immediately will result in arrest and seizure of asset...
#
# 🔍 Stage 1 - Spam Detection:
#     Result:     Ham
#     Confidence: 60.6%
#
# 📊 FINAL CLASSIFICATION:
#     Result:     ✅ Legitimate Email (Ham)
#     Risk Level: Low
#
# 💡 ADVICE:
#     This email appears to be legitimate, but always verify sender addresses.
#
#
# >>> Email #5
# 📧 EMAIL CLASSIFICATION RESULT
#
# 📝 Email Preview:
#     ALERT: Your computer has been infected!
#
#     We have detected a serious virus on your computer. Your personal data is at risk.
#     Call Microsoft Support immediately at 1-800-FAKE-HELP to remove t...
#
# 🔍 Stage 1 - Spam Detection:
#     Result:     Spam
#     Confidence: 99.2%
#
# 🎯 Stage 2 - Phishing Type Classification:
#     Prediction: legitimate
#     Confidence: 42.9%
#     2nd Best:   social_engineering (36.0%)
#
# 🔀 CONFLICT DETECTED
#     ⚠️ CONFLICTING PREDICTIONS: Our spam detector flagged this as spam (99.2% confident), but the phishing classifier suggested 'legitimate' (42.9% confident). Showing next most likely phishing type instead.
#
# 📊 FINAL CLASSIFICATION:
#     Result:     ⚠️ 🎭 Social Engineering (Uncertain)
#     Risk Level: Medium-High
#
# 💡 ADVICE:
#     Verify requests through official channels before taking action. Note: There is some uncertainty in this classification. Exercise extra caution.

# %% [markdown]
# ## Batch Classification

# %%
batch_results = classify_batch(test_emails, spam_model, spam_vectorizer, phishing_model, phishing_vectorizer)
print("Batch Classification Results:")
batch_results
# Out:
# Batch Classification Results:
#                                        email_preview spam_detection  \
# 0  Hi John,\n    \n    Just wanted to follow up o...            Ham
# 1  URGENT: Your account has been compromised!\n  ...           Spam
# 2  Congratulations! You have been selected as the...           Spam
# 3  FINAL NOTICE: IRS Tax Violation\n    \n    Thi...            Ham
# 4  ALERT: Your computer has been infected!\n    \...           Spam
#
#   spam_confidence       phishing_type phishing_confidence  \
# 0          100.0%                 N/A                 N/A
# 1           99.3%  social_engineering               45.3%
# 2          100.0%      financial_scam               96.6%
# 3           60.6%                 N/A                 N/A
# 4           99.2%          legitimate               42.9%
#
#         alternative_type alternative_confidence has_conflict  \
# 0                   None                    N/A           No
# 1  credential_harvesting                  37.0%           No
# 2             legitimate                   1.8%           No
# 3                   None                    N/A           No
# 4     social_engineering                  36.0%       ⚠️ Yes
#
#                   final_classification   risk_level
# 0             ✅ Legitimate Email (Ham)          Low
# 1                 🎭 Social Engineering       Medium
# 2                     💰 Financial Scam         High
# 3             ✅ Legitimate Email (Ham)          Low
# 4  ⚠️ 🎭 Social Engineering (Uncertain)  Medium-High

# %% [markdown]
# ## Interactive Classification (Enter Your Own Email)

# %%
# Try your own email
your_email = """
Storage
Don't risk losing your photos, videos, contacts, files and personal private data.

96%
●	Photos	Full
●	Files	Full
●	Family	Full
●	E-mails	Full
●	Device backup	Almost Full
johndoe24 You may not be able to send or receive emails. To continue using cloud services, please free up space or upgrade your storage. Your files are safe for now, but may be deleted if the cloud is not refreshed.

Upgrade now and get an extra 50 GB bonus storage. Don't wait!
This special offer expires in 4 minutes et 39 seconds

UPDATE
"""

result = classify_email(your_email, spam_model, spam_vectorizer, phishing_model, phishing_vectorizer)
display_result(result)
# Out:
# 📧 EMAIL CLASSIFICATION RESULT
#
# 📝 Email Preview:
#
# Storage
# Don't risk losing your photos, videos, contacts, files and personal private data.
#
# 96%
# ●	Photos	Full
# ●	Files	Full
# ●	Family	Full
# ●	E-mails	Full
# ●	Device backup	Almost Full
# johndoe24 You may no...
#
# 🔍 Stage 1 - Spam Detection:
#     Result:     Spam
#     Confidence: 92.8%
#
# 🎯 Stage 2 - Phishing Type Classification:
#     Prediction: legitimate
#     Confidence: 60.5%
#     2nd Best:   urgency (18.6%)
#
# 🔀 CONFLICT DETECTED
#     ⚠️ CONFLICTING PREDICTIONS: Our spam detector flagged this as spam (92.8% confident), but the phishing classifier suggested 'legitimate' (60.5% confident). Showing next most likely phishing type instead.
#
# 📊 FINAL CLASSIFICATION:
#     Result:     ⚠️ ⏰ Urgency Scam (Uncertain)
#     Risk Level: Medium-High
#
# 💡 ADVICE:
#     Legitimate organizations rarely demand immediate action. Take your time and verify. Note: There is some uncertainty in this classification. Exercise extra caution.
